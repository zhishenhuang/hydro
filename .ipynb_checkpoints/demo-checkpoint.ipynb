# %%
import xarray as xr
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
# %matplotlib notebook
# %matplotlib inline
import torch
import torch.nn as nn
import torch.optim as optim
import os,sys
import random
from skimage.transform import resize
import models
sys.path.insert(0,'/home/huangz78/hydro/unet3d/')
import torch.fft as F
from models.unet3d_model import UNet3D,ResidualUNet3D 
from models.dnet import weights_init,Discriminator
from models.utils import *
from train import gan_train,noise_generate
from importlib import reload
from scipy.interpolate import griddata

from torch.autograd import Variable
import copy

manualSeed = 999
#manualSeed = random.randint(1, 10000) # use if you want new results
print("Random Seed: ", manualSeed)
random.seed(manualSeed)
torch.manual_seed(manualSeed)
# Out:
# Random Seed:  999

# %% [markdown]
# # Is denoising in the Fourier domain a good idea?

# %%
x  = torch.tensor(np.linspace(0,2*np.pi,256))
y  = torch.sin(x)
z  = torch.ones_like(x) * 0.5
yy = y + z

f  = F.fft(y)
ff = F.fft(yy)

plt.figure()
plt.plot(torch.abs(f[0:50]),label='f')
# plt.plot(torch.abs(ff),label='ff')
plt.legend(loc='best')
# plt.yscale('log')
plt.show()

plt.figure()
# plt.plot(torch.abs(f),label='f')
plt.plot(torch.abs(ff[0:50]),label='ff')
plt.legend(loc='best')
# plt.yscale('log')
plt.show()

# %%
reload(models.utils)
from models.utils import illustrate, visualization

# %%
errordata.files
# Out:
# ['g_loss',
#  'd_loss',
#  'val_loss',
#  'nrmse_train',
#  'l1_train',
#  'nrmse_val',
#  'l1_val']

# %%
a = torch.randn((2,1,2,320,320))
b = torch.randn((320,320))
(a * b).shape
# Out:
# torch.Size([2, 1, 2, 320, 320])

# %% [markdown]
# # check conservation of mass

# %%
datapath = '/mnt/shared_b/data/hydro_simulations/data/'
ncfiles = list([])
for file in os.listdir(datapath):
    if file.endswith(".nc"):
        ncfiles.append(file)
print('Total amount of files:', len(ncfiles))
img_size = 320
dep = 41

batchsize = 5
fileexp_inds = [7736+i for i in range(batchsize)]

dyn   = torch.zeros((batchsize,1,dep,img_size,img_size))    # load one sample, show it
noise = torch.zeros((batchsize,1,dep,img_size,img_size))    # make a noise sample, add it to the ground truth, show it

for fileexp_ind in range(len(fileexp_inds)):
    filename = ncfiles[fileexp_inds[fileexp_ind]]
    sim = xr.open_dataarray(datapath+filename)
    # val.append(np.max(np.array(sim)[:dep,:,:].flatten()))
    sim.close()
    for t in range(dep):
        dyn[fileexp_ind,0,t,:,:] = torch.tensor( sim.isel(t=t)[:img_size,:img_size].values )

# dyn   = np.zeros((1,1,dep,256,256))    # load one sample, show it
# noise = np.zeros((1,1,dep,256,256))    # make a noise sample, add it to the ground truth, show it
# for t in range(dep):
#     dyn[0,0,t,:,:] = resize(sim.isel(t=t)[:img_size,:img_size].values,(256,256),anti_aliasing=True)
# Out:
# Total amount of files: 13798

# %%
# check conservation of mass

mass = np.zeros(dep)
for ind in range(dep):
    img = dyn[0,0,ind,:,:]
    mass[ind] = integration_over_sphere(img)
plt.scatter(range(dep),mass)
plt.show()

# %%
img = dyn[0,0,0,:,:]
plt.imshow(img,origin='lower')
plt.colorbar()
plt.show()

# %%
def compute_mass(imgs,Rrho=1,Rz=1):
    '''
    computing through cylindrical coordinate
    '''
    drho = Rrho / imgs.shape[3]
    dz   = Rz   / imgs.shape[4]
    metrics = torch.linspace(0,Rrho,imgs.shape[4]).repeat(imgs.shape[3],1)
    integrand = imgs * metrics
    mass = 2*np.pi * torch.sum(integrand,dim=(3,4)) * drho * dz 
    return torch.squeeze(mass)

# %%
compute_mass(dyn)
# Out:
# > <ipython-input-24-455078b5c62c>(6)compute_mass()
#       4     '''
#       5     breakpoint()
# ----> 6     drho = Rrho / imgs.shape[3]
#       7     dz   = Rz   / imgs.shape[4]
#       8
#
# ipdb> unt 11
# > <ipython-input-24-455078b5c62c>(11)compute_mass()
#       8
#       9     metrics = torch.linspace(0,Rrho,imgs.shape[4]).repeat(imgs.shape[3],1)
#      10     integrand = imgs * metrics
# ---> 11     mass = 2*np.pi * torch.sum(integrand,dim=(3,4)) * drho * dz
#      12     return torch.squeeze(mass)
#
# ipdb> n
# > <ipython-input-24-455078b5c62c>(12)compute_mass()
#       8
#       9     metrics = torch.linspace(0,Rrho,imgs.shape[4]).repeat(imgs.shape[3],1)
#      10     integrand = imgs * metrics
#      11     mass = 2*np.pi * torch.sum(integrand,dim=(3,4)) * drho * dz
# ---> 12     return torch.squeeze(mass)
#
# ipdb> p torch.squeeze(mass).shape
# torch.Size([5, 41])
# ipdb> q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-25-067a601acb21> in <module>
# ----> 1 compute_mass(dyn)
#
# <ipython-input-24-455078b5c62c> in compute_mass(imgs, Rrho, Rz)
#      10     integrand = imgs * metrics
#      11     mass = 2*np.pi * torch.sum(integrand,dim=(3,4)) * drho * dz
# ---> 12     return torch.squeeze(mass)
#
# <ipython-input-24-455078b5c62c> in compute_mass(imgs, Rrho, Rz)
#      10     integrand = imgs * metrics
#      11     mass = 2*np.pi * torch.sum(integrand,dim=(3,4)) * drho * dz
# ---> 12     return torch.squeeze(mass)
#
# /opt/anaconda/envs/pyenv/lib/python3.7/bdb.py in trace_dispatch(self, frame, event, arg)
#      86             return # None
#      87         if event == 'line':
# ---> 88             return self.dispatch_line(frame)
#      89         if event == 'call':
#      90             return self.dispatch_call(frame, arg)
#
# /opt/anaconda/envs/pyenv/lib/python3.7/bdb.py in dispatch_line(self, frame)
#     111         if self.stop_here(frame) or self.break_here(frame):
#     112             self.user_line(frame)
# --> 113             if self.quitting: raise BdbQuit
#     114         return self.trace_dispatch
#     115
#
# BdbQuit:

# %%
mass = np.zeros(dep)
for ind in range(dep):
    img = dyn[0,0,ind,:,:]
    mass[ind] = compute_mass(img)
plt.scatter(range(dep),mass)
plt.show()

# %%
def compute_mass(rho, R, z):
    dR = R[1] - R[0]
    dz = z[1] - z[0]
    m = sum(2*np.pi*R[:]*rho[:])*dR*dz
    return m

# %%
grid_r, grid_theta = np.mgrid[0:1:301j, np.pi/2:np.pi:301j]

# %%
plt.imshow(grid_r.T,origin='lower')
plt.colorbar()
plt.title('r grid')
plt.show()

plt.imshow(grid_theta.T,origin='lower')
plt.colorbar()
plt.title('theta grid')
plt.show()

# %%
def integration_over_sphere(img,img_size=320,grid_len=300,method='cubic',R=1,Rx=1,Ry=1):
    
    grid_r, grid_theta = np.mgrid[0:R:301j, np.pi/2:np.pi:301j]
    dr = 1/grid_len
    dtheta = np.pi/(2*grid_len)
    Cartesian_grid = [[i/img_size*Rx,j/img_size*Ry] for i in range(img_size) for j in range(img_size)]
    radius = lambda x,y: np.sqrt(x**2 + y**2)
    theta  = lambda x,y: np.arctan(x/y) + np.pi/2
    
    Spherical_grid = []
    vals = []
    for point in Cartesian_grid:
        if point[0]==0:
            Spherical_grid.append([point[1],np.pi/2])
        elif (point[1]==0) and (point[0]!=0):
            Spherical_grid.append([point[0],np.pi])
        else:
            Spherical_grid.append([radius(point[0],point[1]),theta(point[0],point[1])])
        vals.append(img[int(point[0]*img_size/Rx),int(point[1]*img_size/Ry)])
        
    Spherical_grid = np.array(Spherical_grid)
#     Cartesian_grid = np.array(Cartesian_grid)
    vals = np.array(vals)

    den_interp = griddata(Spherical_grid, vals, (grid_r, grid_theta), method=method).T
    metric = (grid_r.T)**2 * np.sin(grid_theta.T)
    
    mass = np.sum(metric * np.nan_to_num(den_interp)) * dr * dtheta
    
    return mass

# %%
plt.scatter(Spherical_grid[:,0],Spherical_grid[:,1],c=vals)
plt.xlabel('radius')
plt.ylabel('theta')
plt.colorbar()
plt.show()

# %%
plt.imshow(den_interp.T, extent=(0,1,np.pi/2,np.pi), origin='lower')
plt.title('Cubic interpolation')
plt.gcf().set_size_inches(6, 6)
plt.colorbar()
plt.xlabel('radius')
plt.ylabel('theta')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(Spherical_grid[:,0],Spherical_grid[:,1],vals)
ax.set_xlabel('r')
ax.set_ylabel('theta')
ax.set_zlabel('val')
plt.show()

# %%
dyn = np.loadtxt('/home/huangz78/hydro/leo1_trada.txt')
heg = 860
wid = 880
dx = 2.558140 * 1e-2 
dy = 2.500000 * 1e-2
dyn = np.reshape(dyn,(heg,wid))
Rx = dx * 320
Ry = dy * 320
R  = min(Rx,Ry)

plt.figure(figsize=(10,8))
plt.imshow(dyn)
plt.colorbar()
plt.show()

# %%
imgslice = dyn[heg//2:heg//2+320,wid//2:wid//2+320]
plt.imshow(imgslice)
plt.colorbar()
plt.show()

# %%
integration_over_sphere(imgslice,R=R,Rx=Rx,Ry=Ry)
# Out:
# 326.62647290951725

# %%
heg = 860
wid = 880
dx = 2.558140 * 1e-2 
dy = 2.500000 * 1e-2

weights = np.array([[i**2+j**2 for j in (np.arange(0,wid)-wid//2)*dy] for i in (np.arange(0,heg)-heg//2)*dx])
plt.figure(figsize=(10,8))
plt.imshow(weights)
plt.colorbar()
plt.show()

summation = np.sum(np.multiply(weights,dyn))*(dx*dy)*4/3*np.pi
print(summation)

# summation = np.zeros((dep))
# for t in range(dep):
#     summation[t] = np.sum(np.multiply(weights,dyn[0,0,t,:,:]))
# plt.figure()
# plt.scatter(range(dep),summation)
# plt.xlabel('frame number')
# plt.ylabel('weighted summation of pixels')
# plt.show()
# Out:
# 384076.717677827

# %%
weights = np.array([[i**2+j**2 for i in np.arange(0,img_size)/img_size] for j in np.arange(0,img_size)/img_size])
plt.figure()
plt.imshow(weights)
plt.colorbar()
plt.show()

summation = np.zeros((dep))
for t in range(dep):
    summation[t] = np.sum(np.multiply(weights,dyn[0,0,t,:,:]))
plt.figure()
plt.scatter(range(dep),summation)
plt.xlabel('frame number')
plt.ylabel('weighted summation of pixels')
plt.show()
# Out:
# Total amount of files: 13798

# %% [markdown]
# # track adversial training errors

# %%
errorRec_path = '/home/huangz78/checkpoints/gan_train_track.npz'
errordata = np.load(errorRec_path)
# %matplotlib inline
visualization(errordata['g_loss'],errordata['d_loss'],errordata['val_loss'],\
              errordata['nrmse_val'],errordata['l1_val'],\
              log_loss=False,log_val=False,log_err=False,window=5)

# %%
plt.figure(figsize=(6,4))
plt.plot(errordata['l1_train'],'k')
plt.title('l1 train')
plt.show()

plt.figure(figsize=(6,4))
plt.plot(errordata['nrmse_train'],'b')
plt.title('nrmse train')
plt.show()

# %% [markdown]
# # check denoised slices

# %%
errorRec_path = '/home/huangz78/checkpoints/gnet_warmup_track.npz'
errordata = np.load(errorRec_path)
# %matplotlib inline
print(errordata.files)
# Out:
# ['g_loss', 'val_loss', 'val_loss_cmp', 'nrmse_train', 'l1_train', 'nrmse_val', 'l1_val', 'nrmse_val_cmp', 'l1_val_cmp']

# %%
visualization(errordata,errordata.files,log=False,figsize=(10,35))

# %%
errorRec_path = '/home/huangz78/checkpoints/wgan_train_track.npz'
errordata = np.load(errorRec_path)
print(errordata.files)
# %matplotlib inline
# Out:
# ['g_loss', 'd_loss', 'Massdiffs', 'nrmse_train', 'l1_train', 'nrmse_val', 'l1_val', 'bce_real', 'bce_fake']

# %%
def visualization(data,labels,\
                  log=False,window=0,figsize=(15,25),fontsize=16):
    nums = len(data)
    colors = ['r','b','g','tab:orange','tab:purple','tab:brown','k',\
              'deeppink','darkblue','darkorange','darkslategray','darkseagreen']
    fig,axs = plt.subplots(nums,1,figsize=figsize)
    for ind in range(nums):
        axs[ind].set_xlabel('iters', fontsize=fontsize)
        axs[ind].set_ylabel(labels[ind], color=colors[ind], fontsize=fontsize)
        if window > 0:
            axs[ind].plot(rolling_mean(data[labels[ind]],window), color=colors[ind])
        else:
            axs[ind].plot(data[labels[ind]], color=colors[ind])
        axs[ind].tick_params(axis='x', labelsize='large')
        axs[ind].tick_params(axis='y', labelcolor=colors[ind],labelsize='large')
        if log:
            axs[ind].set_yscale('log')
    plt.show()

# %%
visualization(errordata,errordata.files,log=False,figsize=(10,35))

# %%
# load a G net
# gnet = UNet3D(1,1,is_segmentation=False,final_sigmoid=False)
gnet = ResidualUNet3D(1,1,num_levels=4,is_segmentation=False,final_sigmoid=False)
gpath = '/home/huangz78/checkpoints/netG_wg.pt'
# gpath = '/home/huangz78/checkpoints/netG_wg_diminishing_super_weight.pt' 
# gpath = '/home/huangz78/checkpoints/netG_warmup.pth'
# gpath = '/home/huangz78/checkpoints/netG_warmup_masspenned.pt'
checkpoint = torch.load(gpath)
gnet.load_state_dict(checkpoint['model_state_dict'],strict=True)
gnet.eval()
print(f' G net is successfully loaded from {gpath}! ')
gnet_params_nums = sum(p.numel() for p in gnet.parameters() if p.requires_grad) 
print('total amount of parameters in gnet: ', gnet_params_nums)
# Out:
#  G net is successfully loaded from /home/huangz78/checkpoints/netG_wg.pt!
# total amount of parameters in gnet:  35067331

# %%
gnet = ResidualUNet3D(1,1,num_levels=5,is_segmentation=False,final_sigmoid=False)
gnet_params_nums = sum(p.numel() for p in gnet.parameters() if p.requires_grad) 
print('total amount of parameters in gnet: ', gnet_params_nums)
# Out:
# total amount of parameters in gnet:  141244355

# %%
dnet = Discriminator(0,ndf=1,sigmoid_on=False,imgsize=(8,320,320)).to('cpu')
dnet_params_nums = sum(p.numel() for p in dnet.parameters() if p.requires_grad) 
print('total amount of parameters in dnet: ', sum(p.numel() for p in dnet.parameters() if p.requires_grad) )# dnet.apply(weights_init)
# Out:
# total amount of parameters in dnet:  2172699

# %%
gnet_params_nums/dnet_params_nums
# Out:
# 65.00870806310492

# %%
datapath = '/mnt/shared_b/data/hydro_simulations/data/'
ncfiles = list([])
for file in os.listdir(datapath):
    if file.endswith(".nc"):
        ncfiles.append(file)
print('Total amount of files:', len(ncfiles))
img_size = 320
dep = 8
fileexp_ind = 1793

# for fileexp_ind in range(len(ncfiles)):
filename = ncfiles[fileexp_ind]
sim = xr.open_dataarray(datapath+filename)

sim.close()
dyn   = torch.zeros((1,1,dep,img_size,img_size))    # load one sample, show it
noise = torch.zeros((1,1,dep,img_size,img_size))    
for t in range(dep):
    dyn[0,0,t,:,:] = torch.tensor( sim.isel(t=t)[:img_size,:img_size].values )
# for t in range(dep):
#     dyn[0,0,t,:,:] = resize(sim.isel(t=t)[:img_size,:img_size].values,(256,256),anti_aliasing=True)

normalize_factor   = 50
dyn[0,0,:,:,:]  = dyn[0,0,:,:,:] / normalize_factor

noise = np.zeros(dyn.shape) # make a noise sample, add it to the ground truth, show it
for t in range(dep): # different noise for each frame when using a 'for' loop
    noise[0,0,t,:,:] = noise_generate(dyn[0,0,t,:,:],mode='const_rand',scaling=dyn.max().numpy()) 
dyn = torch.tensor(dyn).to(torch.float); noise = torch.tensor(noise).to(torch.float)
# %matplotlib inline

# illustrate(dyn,vmin=-np.inf,vmax=np.inf,title='ground truth dynamics')
# illustrate(dyn + noise,vmin=-np.inf,vmax=np.inf,title='noisy dynamics')
# illustrate(torch.divide(noise.abs(),dyn),vmin=0,vmax=.1,title='relative L1 error')
# Out:
# Total amount of files: 13798
# /opt/anaconda/envs/pyenv/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %%
# %matplotlib inline
from IPython.display import clear_output

plt.figure()
for i in range(16):
    plt.imshow(dyn[0,0,i,:,:],origin='lower')
    plt.colorbar()
    plt.clim(0, .8)
    plt.title('Frame %d' % (i+1))
    plt.show()
    clear_output(wait=True)

# %%
# apply denoiser, show the outcome
noisy_dyn = noise + dyn
denoised_dyn = gnet(noisy_dyn).clamp(min=0).detach()

print('un-denoised L2 err: ',(torch.norm(noisy_dyn - dyn)/torch.norm(dyn)).item())
print('denoised    L2 err: ', (torch.norm(denoised_dyn - dyn)/torch.norm(dyn)).item())
print('un-denoised L1 err: ',(torch.norm(noisy_dyn - dyn,p=1)/torch.norm(dyn,p=1)).item())
print('denoised    L1 err: ', (torch.norm(denoised_dyn - dyn,p=1)/torch.norm(dyn,p=1)).item())
illustrate(dyn,vmin=0,vmax=0.5,title='ground truth')
illustrate(denoised_dyn,vmin=0,vmax=0.5,title='denoised dynamics')
# Out:
# un-denoised L2 err:  0.20811423659324646
# denoised    L2 err:  0.10176226496696472
# un-denoised L1 err:  0.2374018132686615
# denoised    L1 err:  0.08369369059801102

# %%
def postprocessor(denoised_dyn,truemass,lr=1e0,maxIter=2000,L=100):
    # loss function = ||x - G(noisy_dyn)||_2^2 + L *|| compute_mass(x) - true_mass ||_2^2
    denoised_dyn_cp = copy.copy(denoised_dyn)
    denoised_dyn = Variable(denoised_dyn, requires_grad=True)
    for t in range(maxIter):
        mass_denoised = compute_mass(denoised_dyn)
        mass_denoised.retain_grad()
        # Compute and print loss using operations on Variables.
        loss = torch.norm(denoised_dyn - denoised_dyn_cp,p=2)**2 + L * torch.norm(mass_denoised - truemass)**2
        print(t, loss.data)

        loss.backward()
        denoised_dyn.data -= lr * denoised_dyn.grad.data

        denoised_dyn.grad.data.zero_() # Manually zero the gradients after updating weights
    return denoised_dyn.data

# %%
truemass = compute_mass(dyn)
further_denoised_dyn = postprocessor(denoised_dyn,truemass)
# Out:
# 0 tensor(1.9239)
# 1 tensor(1.8261)
# 2 tensor(1.7333)
# 3 tensor(1.6452)
# 4 tensor(1.5616)
# 5 tensor(1.4822)
# 6 tensor(1.4069)
# 7 tensor(1.3354)
# 8 tensor(1.2675)
# 9 tensor(1.2031)
# 10 tensor(1.1420)
# 11 tensor(1.0839)
# 12 tensor(1.0288)
# 13 tensor(0.9766)
# 14 tensor(0.9269)
# 15 tensor(0.8798)
# 16 tensor(0.8351)
# 17 tensor(0.7927)
# 18 tensor(0.7524)
# 19 tensor(0.7141)
# 20 tensor(0.6778)
# 21 tensor(0.6434)
# 22 tensor(0.6107)
# 23 tensor(0.5797)
# 24 tensor(0.5502)
# 25 tensor(0.5222)
# 26 tensor(0.4957)
# 27 tensor(0.4705)
# 28 tensor(0.4466)
# 29 tensor(0.4239)
# 30 tensor(0.4024)
# 31 tensor(0.3819)
# 32 tensor(0.3625)
# 33 tensor(0.3441)
# 34 tensor(0.3266)
# 35 tensor(0.3100)
# 36 tensor(0.2942)
# 37 tensor(0.2793)
# 38 tensor(0.2651)
# 39 tensor(0.2516)
# 40 tensor(0.2388)
# 41 tensor(0.2267)
# 42 tensor(0.2152)
# 43 tensor(0.2042)
# 44 tensor(0.1939)
# 45 tensor(0.1840)
# 46 tensor(0.1747)
# 47 tensor(0.1658)
# 48 tensor(0.1573)
# 49 tensor(0.1494)
# 50 tensor(0.1418)
# 51 tensor(0.1346)
# 52 tensor(0.1277)
# 53 tensor(0.1212)
# 54 tensor(0.1151)
# 55 tensor(0.1092)
# 56 tensor(0.1037)
# 57 tensor(0.0984)
# 58 tensor(0.0934)
# 59 tensor(0.0887)
# 60 tensor(0.0841)
# 61 tensor(0.0799)
# 62 tensor(0.0758)
# 63 tensor(0.0720)
# 64 tensor(0.0683)
# 65 tensor(0.0648)
# 66 tensor(0.0615)
# 67 tensor(0.0584)
# 68 tensor(0.0554)
# 69 tensor(0.0526)
# 70 tensor(0.0499)
# 71 tensor(0.0474)
# 1186 tensor(3.5527e-13)
# 1187 tensor(3.5527e-13)
# 1188 tensor(3.5527e-13)
# 1189 tensor(0.)
# 1190 tensor(0.)
# 1191 tensor(0.)
# 1192 tensor(0.)
# 1193 tensor(0.)
# 1194 tensor(0.)
# 1195 tensor(0.)
# 1196 tensor(0.)
# 1197 tensor(0.)
# 1198 tensor(0.)
# 1199 tensor(0.)
# 1200 tensor(0.)
# 1201 tensor(0.)
# 1202 tensor(0.)
# 1203 tensor(0.)
# 1204 tensor(0.)
# 1205 tensor(0.)
# 1206 tensor(0.)
# 1207 tensor(0.)
# 1208 tensor(0.)
# 1209 tensor(0.)
# 1210 tensor(0.)
# 1211 tensor(0.)
# 1212 tensor(0.)
# 1213 tensor(0.)
# 1214 tensor(0.)
# 1215 tensor(0.)
# 1216 tensor(0.)
# 1217 tensor(0.)
# 1218 tensor(0.)
# 1219 tensor(0.)
# 1220 tensor(0.)
# 1221 tensor(0.)
# 1222 tensor(0.)
# 1223 tensor(0.)
# 1224 tensor(0.)
# 1225 tensor(0.)
# 1226 tensor(0.)
# 1227 tensor(0.)
# 1228 tensor(0.)
# 1229 tensor(0.)
# 1230 tensor(0.)
# 1231 tensor(0.)
# 1232 tensor(0.)
# 1233 tensor(0.)
# 1234 tensor(0.)
# 1235 tensor(0.)
# 1236 tensor(0.)
# 1237 tensor(0.)
# 1238 tensor(0.)
# 1239 tensor(0.)
# 1240 tensor(0.)
# 1241 tensor(0.)
# 1242 tensor(0.)
# 1243 tensor(0.)
# 1244 tensor(0.)
# 1245 tensor(0.)
# 1246 tensor(0.)
# 1247 tensor(0.)
# 1248 tensor(0.)
# 1249 tensor(0.)
# 1250 tensor(0.)
# 1251 tensor(0.)
# 1252 tensor(0.)
# 1253 tensor(0.)
# 1254 tensor(0.)
# 1255 tensor(0.)
# 1256 tensor(0.)
# 1257 tensor(0.)
# 1258 tensor(0.)
# 1259 tensor(0.)
# 1260 tensor(0.)
# 1261 tensor(0.)
# 1262 tensor(0.)
# 1263 tensor(0.)
# 1264 tensor(0.)
# 1265 tensor(0.)
# 1266 tensor(0.)
# 1267 tensor(0.)
# 1268 tensor(0.)
# 1269 tensor(0.)
# 1270 tensor(0.)
# 1271 tensor(0.)
# 1272 tensor(0.)
# 1273 tensor(0.)
# 1274 tensor(0.)
# 1275 tensor(0.)
# 1276 tensor(0.)
# 1277 tensor(0.)
# 1278 tensor(0.)
# 1279 tensor(0.)
# 1280 tensor(0.)
# 1281 tensor(0.)
# 1282 tensor(0.)
# 1283 tensor(0.)
# 1284 tensor(0.)
# 1285 tensor(0.)
# 1286 tensor(0.)
# 1287 tensor(0.)
# 1288 tensor(0.)
# 1289 tensor(0.)
# 1290 tensor(0.)
# 1291 tensor(0.)
# 1292 tensor(0.)
# 1293 tensor(0.)
# 1294 tensor(0.)
# 1295 tensor(0.)
# 1296 tensor(0.)
# 1297 tensor(0.)
# 1298 tensor(0.)
# 1299 tensor(0.)
# 1300 tensor(0.)
# 1301 tensor(0.)
# 1302 tensor(0.)
# 1303 tensor(0.)
# 1304 tensor(0.)
# 1305 tensor(0.)
# 1306 tensor(0.)
# 1307 tensor(0.)
# 1308 tensor(0.)
# 1309 tensor(0.)
# 1310 tensor(0.)
# 1311 tensor(0.)
# 1312 tensor(0.)
# 1313 tensor(0.)
# 1314 tensor(0.)
# 1315 tensor(0.)
# 1316 tensor(0.)
# 1317 tensor(0.)
# 1318 tensor(0.)
# 1319 tensor(0.)
# 1320 tensor(0.)
# 1321 tensor(0.)
# 1322 tensor(0.)
# 1323 tensor(0.)
# 1324 tensor(0.)
# 1325 tensor(0.)
# 1326 tensor(0.)
# 1327 tensor(0.)
# 1328 tensor(0.)
# 1329 tensor(0.)
# 1330 tensor(0.)
# 1331 tensor(0.)
# 1332 tensor(0.)
# 1333 tensor(0.)
# 1334 tensor(0.)
# 1335 tensor(0.)
# 1336 tensor(0.)
# 1337 tensor(0.)
# 1338 tensor(0.)
# 1339 tensor(0.)
# 1340 tensor(0.)
# 1341 tensor(0.)
# 1342 tensor(0.)
# 1343 tensor(0.)
# 1344 tensor(0.)
# 1345 tensor(0.)
# 1346 tensor(0.)
# 1347 tensor(0.)
# 1348 tensor(0.)
# 1349 tensor(0.)
# 1350 tensor(0.)
# 1351 tensor(0.)
# 1352 tensor(0.)
# 1353 tensor(0.)
# 1354 tensor(0.)
# 1355 tensor(0.)
# 1356 tensor(0.)
# 1357 tensor(0.)
# 1358 tensor(0.)
# 1359 tensor(0.)
# 1360 tensor(0.)
# 1361 tensor(0.)
# 1362 tensor(0.)
# 1363 tensor(0.)
# 1364 tensor(0.)
# 1365 tensor(0.)
# 1366 tensor(0.)
# 1367 tensor(0.)
# 1368 tensor(0.)
# 1369 tensor(0.)
# 1370 tensor(0.)
# 1371 tensor(0.)
# 1372 tensor(0.)
# 1373 tensor(0.)
# 1374 tensor(0.)
# 1375 tensor(0.)
# 1376 tensor(0.)
# 1377 tensor(0.)
# 1378 tensor(0.)
# 1379 tensor(0.)
# 1380 tensor(0.)
# 1381 tensor(0.)
# 1382 tensor(0.)
# 1383 tensor(0.)
# 1384 tensor(0.)
# 1385 tensor(0.)
# 1386 tensor(0.)
# 1387 tensor(0.)
# 1388 tensor(0.)
# 1389 tensor(0.)
# 1390 tensor(0.)
# 1391 tensor(0.)
# 1392 tensor(0.)
# 1393 tensor(0.)
# 1394 tensor(0.)
# 1395 tensor(0.)
# 1396 tensor(0.)
# 1397 tensor(0.)
# 1398 tensor(0.)
# 1399 tensor(0.)
# 1400 tensor(0.)
# 1401 tensor(0.)
# 1402 tensor(0.)
# 1403 tensor(0.)
# 1404 tensor(0.)
# 1405 tensor(0.)
# 1406 tensor(0.)
# 1407 tensor(0.)
# 1408 tensor(0.)
# 1409 tensor(0.)
# 1410 tensor(0.)
# 1411 tensor(0.)
# 1412 tensor(0.)
# 1413 tensor(0.)
# 1414 tensor(0.)
# 1415 tensor(0.)
# 1416 tensor(0.)
# 1417 tensor(0.)
# 1418 tensor(0.)
# 1419 tensor(0.)
# 1420 tensor(0.)
# 1421 tensor(0.)
# 1422 tensor(0.)
# 1423 tensor(0.)
# 1424 tensor(0.)
# 1425 tensor(0.)
# 1426 tensor(0.)
# 1427 tensor(0.)
# 1428 tensor(0.)
# 1429 tensor(0.)
# 1430 tensor(0.)
# 1431 tensor(0.)
# 1432 tensor(0.)
# 1433 tensor(0.)
# 1434 tensor(0.)
# 1435 tensor(0.)
# 1436 tensor(0.)
# 1437 tensor(0.)
# 1438 tensor(0.)
# 1439 tensor(0.)
# 1440 tensor(0.)
# 1441 tensor(0.)
# 1442 tensor(0.)
# 1443 tensor(0.)
# 1444 tensor(0.)
# 1445 tensor(0.)
# 1446 tensor(0.)
# 1447 tensor(0.)
# 1448 tensor(0.)
# 1449 tensor(0.)
# 1450 tensor(0.)
# 1451 tensor(0.)
# 1452 tensor(0.)
# 1453 tensor(0.)
# 1454 tensor(0.)
# 1455 tensor(0.)
# 1456 tensor(0.)
# 1457 tensor(0.)
# 1458 tensor(0.)
# 1459 tensor(0.)
# 1460 tensor(0.)
# 1461 tensor(0.)
# 1462 tensor(0.)
# 1463 tensor(0.)
# 1464 tensor(0.)
# 1465 tensor(0.)
# 1466 tensor(0.)
# 1467 tensor(0.)
# 1468 tensor(0.)
# 1469 tensor(0.)
# 1470 tensor(0.)
# 1471 tensor(0.)
# 1472 tensor(0.)
# 1473 tensor(0.)
# 1474 tensor(0.)
# 1475 tensor(0.)
# 1476 tensor(0.)
# 1477 tensor(0.)
# 1478 tensor(0.)
# 1479 tensor(0.)
# 1480 tensor(0.)
# 1481 tensor(0.)
# 1482 tensor(0.)
# 1483 tensor(0.)
# 1484 tensor(0.)
# 1485 tensor(0.)
# 1486 tensor(0.)
# 1487 tensor(0.)
# 1488 tensor(0.)
# 1489 tensor(0.)
# 1490 tensor(0.)
# 1491 tensor(0.)
# 1492 tensor(0.)
# 1493 tensor(0.)
# 1494 tensor(0.)
# 1495 tensor(0.)
# 1496 tensor(0.)
# 1497 tensor(0.)
# 1498 tensor(0.)
# 1499 tensor(0.)
# 1500 tensor(0.)
# 1501 tensor(0.)
# 1502 tensor(0.)
# 1503 tensor(0.)
# 1504 tensor(0.)
# 1505 tensor(0.)
# 1506 tensor(0.)
# 1507 tensor(0.)
# 1508 tensor(0.)
# 1509 tensor(0.)
# 1510 tensor(0.)
# 1511 tensor(0.)
# 1512 tensor(0.)
# 1513 tensor(0.)
# 1514 tensor(0.)
# 1515 tensor(0.)
# 1516 tensor(0.)
# 1517 tensor(0.)
# 1518 tensor(0.)
# 1519 tensor(0.)
# 1520 tensor(0.)
# 1521 tensor(0.)
# 1522 tensor(0.)
# 1523 tensor(0.)
# 1524 tensor(0.)
# 1525 tensor(0.)
# 1526 tensor(0.)
# 1527 tensor(0.)
# 1528 tensor(0.)
# 1529 tensor(0.)
# 1530 tensor(0.)
# 1531 tensor(0.)
# 1532 tensor(0.)
# 1533 tensor(0.)
# 1534 tensor(0.)
# 1535 tensor(0.)
# 1536 tensor(0.)
# 1537 tensor(0.)
# 1538 tensor(0.)
# 1539 tensor(0.)
# 1540 tensor(0.)
# 1541 tensor(0.)
# 1542 tensor(0.)
# 1543 tensor(0.)
# 1544 tensor(0.)
# 1545 tensor(0.)
# 1546 tensor(0.)
# 1547 tensor(0.)
# 1548 tensor(0.)
# 1549 tensor(0.)
# 1550 tensor(0.)
# 1551 tensor(0.)
# 1552 tensor(0.)
# 1553 tensor(0.)
# 1554 tensor(0.)
# 1555 tensor(0.)
# 1556 tensor(0.)
# 1557 tensor(0.)
# 1558 tensor(0.)
# 1559 tensor(0.)
# 1560 tensor(0.)
# 1561 tensor(0.)
# 1562 tensor(0.)
# 1563 tensor(0.)
# 1564 tensor(0.)
# 1565 tensor(0.)
# 1566 tensor(0.)
# 1567 tensor(0.)
# 1568 tensor(0.)
# 1569 tensor(0.)
# 1570 tensor(0.)
# 1571 tensor(0.)
# 1572 tensor(0.)
# 1573 tensor(0.)
# 1574 tensor(0.)
# 1575 tensor(0.)
# 1576 tensor(0.)
# 1577 tensor(0.)
# 1578 tensor(0.)
# 1579 tensor(0.)
# 1580 tensor(0.)
# 1581 tensor(0.)
# 1582 tensor(0.)
# 1583 tensor(0.)
# 1584 tensor(0.)
# 1585 tensor(0.)
# 1586 tensor(0.)
# 1587 tensor(0.)
# 1588 tensor(0.)
# 1589 tensor(0.)
# 1590 tensor(0.)
# 1591 tensor(0.)
# 1592 tensor(0.)
# 1593 tensor(0.)
# 1594 tensor(0.)
# 1595 tensor(0.)
# 1596 tensor(0.)
# 1597 tensor(0.)
# 1598 tensor(0.)
# 1599 tensor(0.)
# 1600 tensor(0.)
# 1601 tensor(0.)
# 1602 tensor(0.)
# 1603 tensor(0.)
# 1604 tensor(0.)
# 1605 tensor(0.)
# 1606 tensor(0.)
# 1607 tensor(0.)
# 1608 tensor(0.)
# 1609 tensor(0.)
# 1610 tensor(0.)
# 1611 tensor(0.)
# 1612 tensor(0.)
# 1613 tensor(0.)
# 1614 tensor(0.)
# 1615 tensor(0.)
# 1616 tensor(0.)
# 1617 tensor(0.)
# 1618 tensor(0.)
# 1619 tensor(0.)
# 1620 tensor(0.)
# 1621 tensor(0.)
# 1622 tensor(0.)
# 1623 tensor(0.)
# 1624 tensor(0.)
# 1625 tensor(0.)
# 1626 tensor(0.)
# 1627 tensor(0.)
# 1628 tensor(0.)
# 1629 tensor(0.)
# 1630 tensor(0.)
# 1631 tensor(0.)
# 1632 tensor(0.)
# 1633 tensor(0.)
# 1634 tensor(0.)
# 1635 tensor(0.)
# 1636 tensor(0.)
# 1637 tensor(0.)
# 1638 tensor(0.)
# 1639 tensor(0.)
# 1640 tensor(0.)
# 1641 tensor(0.)
# 1642 tensor(0.)
# 1643 tensor(0.)
# 1644 tensor(0.)
# 1645 tensor(0.)
# 1646 tensor(0.)
# 1647 tensor(0.)
# 1648 tensor(0.)
# 1649 tensor(0.)
# 1650 tensor(0.)
# 1651 tensor(0.)
# 1652 tensor(0.)
# 1653 tensor(0.)
# 1654 tensor(0.)
# 1655 tensor(0.)
# 1656 tensor(0.)
# 1657 tensor(0.)
# 1658 tensor(0.)
# 1659 tensor(0.)
# 1660 tensor(0.)
# 1661 tensor(0.)
# 1662 tensor(0.)
# 1663 tensor(0.)
# 1664 tensor(0.)
# 1665 tensor(0.)
# 1666 tensor(0.)
# 1907 tensor(0.)
# 1908 tensor(0.)
# 1909 tensor(0.)
# 1910 tensor(0.)
# 1911 tensor(0.)
# 1912 tensor(0.)
# 1913 tensor(0.)
# 1914 tensor(0.)
# 1915 tensor(0.)
# 1916 tensor(0.)
# 1917 tensor(0.)
# 1918 tensor(0.)
# 1919 tensor(0.)
# 1920 tensor(0.)
# 1921 tensor(0.)
# 1922 tensor(0.)
# 1923 tensor(0.)
# 1924 tensor(0.)
# 1925 tensor(0.)
# 1926 tensor(0.)
# 1927 tensor(0.)
# 1928 tensor(0.)
# 1929 tensor(0.)
# 1930 tensor(0.)
# 1931 tensor(0.)
# 1932 tensor(0.)
# 1933 tensor(0.)
# 1934 tensor(0.)
# 1935 tensor(0.)
# 1936 tensor(0.)
# 1937 tensor(0.)
# 1938 tensor(0.)
# 1939 tensor(0.)
# 1940 tensor(0.)
# 1941 tensor(0.)
# 1942 tensor(0.)
# 1943 tensor(0.)
# 1944 tensor(0.)
# 1945 tensor(0.)
# 1946 tensor(0.)
# 1947 tensor(0.)
# 1948 tensor(0.)
# 1949 tensor(0.)
# 1950 tensor(0.)
# 1951 tensor(0.)
# 1952 tensor(0.)
# 1953 tensor(0.)
# 1954 tensor(0.)
# 1955 tensor(0.)
# 1956 tensor(0.)
# 1957 tensor(0.)
# 1958 tensor(0.)
# 1959 tensor(0.)
# 1960 tensor(0.)
# 1961 tensor(0.)
# 1962 tensor(0.)
# 1963 tensor(0.)
# 1964 tensor(0.)
# 1965 tensor(0.)
# 1966 tensor(0.)
# 1967 tensor(0.)
# 1968 tensor(0.)
# 1969 tensor(0.)
# 1970 tensor(0.)
# 1971 tensor(0.)
# 1972 tensor(0.)
# 1973 tensor(0.)
# 1974 tensor(0.)
# 1975 tensor(0.)
# 1976 tensor(0.)
# 1977 tensor(0.)
# 1978 tensor(0.)
# 1979 tensor(0.)
# 1980 tensor(0.)
# 1981 tensor(0.)
# 1982 tensor(0.)
# 1983 tensor(0.)
# 1984 tensor(0.)
# 1985 tensor(0.)
# 1986 tensor(0.)
# 1987 tensor(0.)
# 1988 tensor(0.)
# 1989 tensor(0.)
# 1990 tensor(0.)
# 1991 tensor(0.)
# 1992 tensor(0.)
# 1993 tensor(0.)
# 1994 tensor(0.)
# 1995 tensor(0.)
# 1996 tensor(0.)
# 1997 tensor(0.)
# 1998 tensor(0.)
# 1999 tensor(0.)

# %%
print('un-denoised L2 err: ',(torch.norm(noisy_dyn - dyn)/torch.norm(dyn)).item())
print('further denoised L2 err: ', (torch.norm(further_denoised_dyn - dyn)/torch.norm(dyn)).item())
print('un-denoised L1 err: ',(torch.norm(noisy_dyn - dyn,p=1)/torch.norm(dyn,p=1)).item())
print('further denoised L1 err: ', (torch.norm(further_denoised_dyn - dyn,p=1)/torch.norm(dyn,p=1)).item())
# Out:
# un-denoised L2 err:  0.20811423659324646
# further denoised L2 err:  0.0912785455584526
# un-denoised L1 err:  0.2374018132686615
# further denoised L1 err:  0.0833263099193573

# %%
illustrate(torch.divide((further_denoised_dyn - dyn).abs(),dyn),vmin=0,vmax=1,title='relative L1 error')
